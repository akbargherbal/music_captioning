# %%
# !gcloud auth login

# %%
# !gsutil cp -r gs://_ .

# %%
# !pip install click torch torchaudio transformers librosa accelerate soundfile bitsandbytes -q

# %%
# !python music_caption.py --dir ./AI_MUSIC_APRIL_2026 --mode detailed

# %%
# rm ./AI_MUSIC_APRIL_2026/*.log

# %%
# !gsutil cp -r ./AI_MUSIC_APRIL_2026/ gs://_
